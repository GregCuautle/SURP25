# %%
import numpy as np
import os, pathlib
import matplotlib.pyplot as plt
os.chdir("/Users/gregcc/Documents/GitHub/SURP25/Microlensing")

# %%
import numpy as np

d0 = np.load("mass_m0.npz")
print(d0.files)  # shows: ['tau_triple','mag_triple','tau_bin_q4',...,'dx_twoB','dy_twoB']

# Photometry (high-res)
tau_triple = d0["tau_triple"]
mag_triple = d0["mag_triple"]
tau_q4     = d0["tau_bin_q4"]
mag_q4     = d0["mag_bin_q4"]
tau_q2     = d0["tau_bin_q2"]
mag_q2     = d0["mag_bin_q2"]

# Astrometry (each has its own tau)
tau_ast3 = d0["tau_ast_triple"]; dx3 = d0["dx_three"]; dy3 = d0["dy_three"]
tau_ast2A = d0["tau_ast_twoA"];  dx2A = d0["dx_twoA"];  dy2A = d0["dy_twoA"]
tau_ast2B = d0["tau_ast_twoB"];  dx2B = d0["dx_twoB"];  dy2B = d0["dy_twoB"]
# Out:
# ['tau_triple', 'mag_triple', 'tau_bin_q4', 'mag_bin_q4', 'tau_bin_q2', 'mag_bin_q2', 'tau_ast_triple', 'dx_three', 'dy_three', 'tau_ast_twoA', 'dx_twoA', 'dy_twoA', 'tau_ast_twoB', 'dx_twoB', 'dy_twoB']

# %%
d1 = np.load("mass_m1.npz")
print(d1.files)  # shows: ['tau_triple','mag_triple','tau_bin_q4',...,'dx_twoB','dy_twoB']

# Photometry (high-res)
tau_triple_1 = d1["tau_triple"]
mag_triple_1 = d1["mag_triple"]
tau_q4_1     = d1["tau_bin_q4"]
mag_q4_1     = d1["mag_bin_q4"]
tau_q2_1     = d1["tau_bin_q2"]
mag_q2_1     = d1["mag_bin_q2"]

# Astrometry (each has its own tau)
tau_ast3_1 = d1["tau_ast_triple"]; dx3_1 = d1["dx_three"]; dy3_1 = d1["dy_three"]
tau_ast2A_1 = d1["tau_ast_twoA"];  dx2A_1 = d1["dx_twoA"];  dy2A_1 = d1["dy_twoA"]
tau_ast2B_1 = d1["tau_ast_twoB"];  dx2B_1 = d1["dx_twoB"];  dy2B_1 = d1["dy_twoB"]
# Out:
# ['tau_triple', 'mag_triple', 'tau_bin_q4', 'mag_bin_q4', 'tau_bin_q2', 'mag_bin_q2', 'tau_ast_triple', 'dx_three', 'dy_three', 'tau_ast_twoA', 'dx_twoA', 'dy_twoA', 'tau_ast_twoB', 'dx_twoB', 'dy_twoB']

# %%
d2 = np.load("mass_m2.npz")
print(d2.files)  # shows: ['tau_triple','mag_triple','tau_bin_q4',...,'dx_twoB','dy_twoB']

# Photometry (high-res)
tau_triple_2 = d2["tau_triple"]
mag_triple_2 = d2["mag_triple"]
tau_q4_2     = d2["tau_bin_q4"]
mag_q4_2     = d2["mag_bin_q4"]
tau_q2_2     = d2["tau_bin_q2"]
mag_q2_2     = d2["mag_bin_q2"]

# Astrometry (each has its own tau)
tau_ast3_2 = d2["tau_ast_triple"]; dx3_2 = d2["dx_three"]; dy3_2 = d2["dy_three"]
tau_ast2A_2 = d2["tau_ast_twoA"];  dx2A_2 = d2["dx_twoA"];  dy2A_2 = d2["dy_twoA"]
tau_ast2B_2 = d2["tau_ast_twoB"];  dx2B_2 = d2["dx_twoB"];  dy2B_2 = d2["dy_twoB"]
# Out:
# ['tau_triple', 'mag_triple', 'tau_bin_q4', 'mag_bin_q4', 'tau_bin_q2', 'mag_bin_q2', 'tau_ast_triple', 'dx_three', 'dy_three', 'tau_ast_twoA', 'dx_twoA', 'dy_twoA', 'tau_ast_twoB', 'dx_twoB', 'dy_twoB']

# %%
plt.plot(dx3, dy3, 'r.', label = 'q3 = 1e-6')
plt.plot(dx3_1, dy3_1,'b.', label = 'q3 = 1e-5')
plt.plot(dx3_2, dy3_2,'g.', label = 'q3 = 1e-4')

#plt.plot(dx3, dy3, 'r-')
#plt.plot(dx3_1, dy3_1,'b-')
#plt.plot(dx3_2, dy3_2,'g-')

plt.plot(dx2A, dy2A, 'k.', label = 'Binary Lens')



plt.xlabel("dx")
plt.ylabel("dy")
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(dx3, dy3, 'r.', label = 'q3 = 1e-6')
plt.plot(dx3_1, dy3_1,'b.', label = 'q3 = 1e-5')
plt.plot(dx3_2, dy3_2,'g.', label = 'q3 = 1e-4')

plt.plot(dx3, dy3, 'r-')
plt.plot(dx3_1, dy3_1,'b-')
plt.plot(dx3_2, dy3_2,'g-')

plt.plot(dx2A, dy2A, 'k.', label = 'Binary Lens')
plt.plot(dx2A_1, dy2A_1, 'k.', label = 'Binary Lens 1')
plt.plot(dx2A_2, dy2A_2, 'k.', label = 'Binary Lens 2')

plt.xlim(0.1, 0.35)
plt.ylim(-0.01, -.002)
plt.xlabel("dx")
plt.ylabel("dy")
plt.grid(True)
plt.legend()
plt.show()
